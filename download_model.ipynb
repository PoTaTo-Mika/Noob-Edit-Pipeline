# %%
export HF_ENDPOINT=https://hf-mirror.com
hf download Laxhar/noob_openpose --local-dir ./checkpoints/weights/noob_openpose
hf download Laxhar/noobai-XL-Vpred-1.0 --include "NoobAI-XL-Vpred-v1.0.safetensors" --local-dir ./checkpoints/weights/noob_vpred_1.0
